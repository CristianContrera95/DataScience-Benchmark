# %% [markdown]
# # Redes Neuronales
#
# En este notebook vamos a construir la unidad básica de las redes neuronales, el Perceptrón. Tiene dos partes:
# 1. **Perceptrón a mano**: primero, vamos a estudiar la función sigmoide y la entropía categórica para un caso sencillo, unidimensional. Vamos a encontrar el mínimo de la función de costo haciendo una exploración exhaustiva del espacio de parámetros, simil GridSearch. Podríamos también hacer la parte de gradiente descendiente, pero excede el alcance de lo que queremos presentar en el curso, y además para eso están las librerías como Keras. De todas formas, si alguien se anima, puede intentarlo y lo ayudamos con algunas pistas.
# 2. **Perceptrón con Keras**: luego, vamos a entrenar un Perceptrón con Keras sobre el mismo dataset. Vamos a usarlo como excusa para presentar las principales características de la librería.
# 3. **Perceptrón 2D**: vamos a entrenar un Perceptrón con Keras sobre un dataset ficticio. Exploramos cómo son las fronteras en 2D. Limitaciones del Perceptrón. Como probablemente no alcance el tiempo en esta clase, esta sección también será el comienzo del siguiente notebook.
#
# ## 1. Perceptrón a mano
#
# El objetivo es ajustar un Perceptrón a los datos del Challenger. Recuerden estos datos tienen un solo feature, la temperatura. ¿Cuántos parámetros tendrá el Perceptrón?
#
# 1. Escribir una función que, dado un vector x y dos parámetros w0 y w1, calcula la función sigmoide. Hacer un plot para algunos parámetros, tratando de obtener los gráficos de la presentación.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set()

# %%
def sigmoid_function(x,w0, w1):
    '''Equivalente a perceptron con funcion de activacion sigmoide'''
    z = w0 + w1*x #notar que es una funcion lineal
    y = 1/(1 + np.exp(-z))   #notar que es una composicion
    return y

# %%
x = np.linspace(-10,10,500)

y = sigmoid_function(x, 0,1)
plt.plot(x,sigmoid_function(x, 0,1), label = 'w0 = 0, w1 = 1')
plt.plot(x,sigmoid_function(x, 0,-1), label = 'w0 = 0, w1 = -1')

plt.legend()
plt.tight_layout()
# plt.savefig('regresion_logistica.png', dpi = 400)

plt.show()

# %% [markdown]
# 2. Escribir una función que, dado la etiqueta de una instancia `y` y una predicción `y_pred`, calcula la función de perdida *entropía cruzada*. Hacer un plot para el caso `y = 0` e `y = 1`, tratando de obtener los gráficos de la presentación.

# %%
def cross_entropy_loss(y, y_pred):
    L = -y*np.log(y_pred) - (1-y)*np.log(1 - y_pred)
    return L

# %%
y = 1
ys_pred = np.linspace(0,1,1000)
plt.plot(ys_pred, cross_entropy_loss(y,ys_pred))
plt.xlabel('y_pred, probabilidad predicha')
plt.ylabel('Perdida')
plt.title('y = 1')
plt.tight_layout()
# plt.savefig('perdida_0.png', dpi = 400)
plt.show()
# Out:
# <ipython-input-4-d9f436ccb69a>:2: RuntimeWarning: divide by zero encountered in log
#   L = -y*np.log(y_pred) - (1-y)*np.log(1 - y_pred)
# <ipython-input-4-d9f436ccb69a>:2: RuntimeWarning: invalid value encountered in multiply
#   L = -y*np.log(y_pred) - (1-y)*np.log(1 - y_pred)

# %% [markdown]
# 3. Escribir una función que, dado las etiquetas muchas instancias `y` y las predicciones `y_pred`, calcula la función de  costo *entropía cruzada* para todas las instancias. PISTA: hacer un `for` sobre las instancias y llamar a la función `cross_entropy_loss` que crearon antes.

# %%
def cross_entropy_cost(y, y_pred):
    ## Un sanity check
    assert y_pred.size == y.size, 'Ojo que los vectores no tienen el mismo tamanio'
    
    y_pred = y_pred.reshape(y_pred.size)
    y = y.reshape(y.size)
    J = 0
    for i in range(y_pred.size):
        J += cross_entropy_loss(y[i], y_pred[i])
    J /= y_pred.size
    return J

# %%
### Por si alguno/a quiere ver por que no usamos esta funcion de costo
def MSE(y,y_pred):
    '''Calcula Mean Squared Error'''
    assert(len(y) == len(y_pred))
    n = len(y)
    return ((y - y_pred)**2).sum()/n

# %% [markdown]
# **Datos del Challenger**
#
# Cargamos los datos usados en la presentación. Nosotros nos encargamos del preprocesamiento y de los gráficos.

# %%
dataset = pd.read_csv('../Data/challenger.csv')
dataset.dropna(inplace = True) # Tiramos los NaN (una sola fila)
dataset['Temperature (C)'] = np.round((dataset['Temperature'] - 32)/1.8,2) # pasamos a celcius
dataset
# Out:
#           Date  Temperature      Damage Incident  Temperature (C)
# 0   04/12/1981           66                    0            18.89
# 1   11/12/1981           70                    1            21.11
# 2      3/22/82           69                    0            20.56
# 4   01/11/1982           68                    0            20.00
# 5   04/04/1983           67                    0            19.44
# 6      6/18/83           72                    0            22.22
# 7      8/30/83           73                    0            22.78
# 8     11/28/83           70                    0            21.11
# 9   02/03/1984           57                    1            13.89
# 10  04/06/1984           63                    1            17.22
# 11     8/30/84           70                    1            21.11
# 12  10/05/1984           78                    0            25.56
# 13  11/08/1984           67                    0            19.44
# 14     1/24/85           53                    1            11.67
# 15  04/12/1985           67                    0            19.44
# 16     4/29/85           75                    0            23.89
# 17     6/17/85           70                    0            21.11
# 18     7/29/85           81                    0            27.22
# 19     8/27/85           76                    0            24.44
# 20  10/03/1985           79                    0            26.11
# 21    10/30/85           75                    1            23.89
# 22    11/26/85           76                    0            24.44
# 23  01/12/1986           58                    1            14.44
# 24     1/28/86           31  Challenger Accident            -0.56

# %%
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Date', y  = 'Temperature (C)', hue = 'Damage Incident', data = dataset, s = 100)
for item in plot.get_xticklabels():
    item.set_rotation(90)
plt.tight_layout()
plt.show()

# %%
# dataset.drop([24], inplace = True)
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Temperature (C)', y  = 'Damage Incident', hue = 'Damage Incident', data = dataset, s = 100)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Variables para entrenamiento**

# %%
X = dataset.drop([24])['Temperature (C)'].values
y = dataset.drop([24])['Damage Incident'].values.astype(int)

# %% [markdown]
# Es muy importante reescalar los datos cuando trabajen con Redes Neuronales

# %%
X_mean = X.mean()
X_std = X.std()
X = (X - X_mean)/X_std

# %% [markdown]
# **Explorando la función de costo**
#
# El objetivo es lograr obtener el gráfico de la función de costo como hicimos la clase anterior. Para ellos, es importante que respondan: ¿cuántos parámetros tiene la función sigmoide/perceptrón?¿Qué tipo de gráfico quieren obtener?
#
# 1. Crear un arreglo con valores para w0 y w1 (`w0s, w1s`)

# %%
w0s = np.linspace(-5,0,50)  # bias
w1s = np.linspace(-5,0,50)  # peso

# %% [markdown]
# 2. Recorrer los dos arreglos y calcular el costo para cada combinación de parámetros `w0, w1`

# %%
#%%time
costos = []
for w0 in w0s:
    for w1 in w1s:
        y_pred = sigmoid_function(X.flatten(), w0,w1)
#         costos.append(MSE(y,y_pred))
        costos.append(cross_entropy_cost(y,y_pred))
costos = np.array(costos)

# %% [markdown]
# 3. Graficar

# %%
W0s, W1s = np.meshgrid(w0s,w1s, indexing = 'ij')
costos_matriz = costos.reshape(w0s.size, w1s.size)

# %%
idxs_minimo = np.unravel_index(costos_matriz.argmin(), costos_matriz.shape)
fig = plt.figure(figsize = (8,6))
ax = fig.gca()

plt.pcolormesh(W0s, W1s,costos_matriz)
ax.contourf(W0s, W1s, costos_matriz)
plt.colorbar()
plt.scatter(W0s[idxs_minimo], W1s[idxs_minimo])
plt.title('Costo en el minimo:' + str(costos_matriz[idxs_minimo]))
plt.xlabel('W0')
plt.ylabel('W1')
plt.tight_layout()
plt.show()

# %%
w0_encontrado = W0s[idxs_minimo]
w1_encontrado = W1s[idxs_minimo]

print('w0 encontrado:', w0_encontrado)
print('w1 encontrado:', w1_encontrado)
# Out:
# w0 encontrado: -1.1224489795918364
# w1 encontrado: -1.6326530612244898

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl

fig = plt.figure(figsize = (8,6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(W0s, W1s,costos_matriz,linewidth=0.0, antialiased=False, cmap = 'plasma')
# ax.view_init(0, 180)
ax.set_xlabel('m')
ax.set_ylabel('b')
ax.set_zlabel('costo')
plt.tight_layout()
plt.colorbar(surf)    
plt.show()

# %% [markdown]
# 4. Graficar la función sigmoide para los parámetros obtenidos.

# %%
X_mean
# Out:
# 20.868695652173916

# %%
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Temperature (C)', y  = 'Damage Incident', hue = 'Damage Incident', data = dataset, s = 100)

x_plot = np.linspace(-5,30,100)
z = (x_plot - X_mean)/X_std
plt.plot(x_plot, sigmoid_function(z,w0_encontrado,w1_encontrado))

plt.axhline(0.5, ls = '--', c = 'r', label = 'probabilidad de 0.5')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Perceptron con Keras
#
#
# Keras es un entorno de desarrollo para Redes Neuronales de alto nivel. Esto quiere decir que es - o al menos trata de ser- más amigable que otros entornos de desarrollo, como por ejemplo TensorFlow. Sin embargo, está basado en TensorFlow, que es quien hace el "trabajo pesado". Una de las principales ventajas de Keras es que es rápido para hacer prototipos, hay muchas funciones de costo, optimizadores y tipo de neuronas implementadas, lo cual lo hacen muy versátil.
#
# Tal vez una desventaja sea que la documentación tiende a ser escueta. Pero por otro lado hay muchos ejemplos y tutoriales en internet que se pueden usar que están buenos.
#
# https://keras.io/getting-started/sequential-model-guide/
#
# Los pasos básicos a seguir con Keras son:
# 1. Definimos un modelo: indicamos cantidad y tipos de neuronas.
# 2. Compilamos el modelo: indicamos función de costo y optimizador.
# 3. Entrenamos el modelo: cantidad de iteraciones y otros parámetros.

# %% [markdown]
# 1. Definimos el modelo. El tipo de modelo se llama `Sequential` y le agregamos una capa (`layer`) con una Neurona `Dense`, con una función de activación `'sigmoid'`.

# %%
import keras
keras.__version__
# Out:
# '2.3.1'

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

model.add( Dense(1, activation='sigmoid') )
model.add( Dense(10, activation='relu') )
model.add( Dense(50, activation='relu') )
model.add( Dense(1, activation='sigmoid') )

# %% [markdown]
# 2. Compilamos el modelo llamando a `model.compile(...)`. Los argumentos más importantes son el optimizador `optimizer`, la pérdida `loss` y, si queremos, un métrica que evalúa durante el entrenamiento. **Importante**: solamente la evalúa, nada más.
#
# La forma en que pasamos los argumentos no es la única que hay, también se pueden crear *objetos* optimizadores y pasarles argumentos de forma más detallada. Mirar algunos ejemplos en la documentación.

# %%
from keras.optimizers import SGD

# %%
opt = SGD(learning_rate=1)

# %%
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, epsilon=None, decay=0.0, amsgrad=False)
# model.compile(optimizer= optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 3. Ver la historia de entrenamiento del modelo. History es un objeto con muchas características, pero tiene guardado la pérdida para cada iteración y la métrica que le hayamos pedido que evalúe.

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

plt.figure()
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# 4. Se pueden ver los pesos que obtuvo

# %%
model.get_layer()

# %%
print(model.get_weights())
# Out:
# [array([[-0.92911553]], dtype=float32), array([-0.78616625], dtype=float32)]

# %%
w0 = model.get_weights()[0][0][0]
w1 = model.get_weights()[1][0]
print(w0,w1)
# Out:
# -0.92911553 -0.78616625

# %% [markdown]
# 5. Y, como en todo modelo, podemos graficar el resultado.

# %%
plt.figure(figsize = (8,4))
plot = sns.scatterplot(x = 'Temperature (C)', y  = 'Damage Incident', hue = 'Damage Incident', data = dataset, s = 100)

x_plot = np.linspace(-5,30,100)
z = (x_plot - X_mean)/X_std
plt.plot(x_plot, model.predict(z))
# plt.plot(x_plot, sigmoid_function(z,w0,w1))

plt.axhline(0.5, ls = '--', c = 'r', label = 'probabilidad de 0.5')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Perceptrón en 2D
#
# Seguimos con la mismas ideas que antes, pero ahora en vez de un feature hay dos. Vamos a generar un dataset sintético con unas funciones que ya vienen incorporadas en scikit-learn.

# %%
from sklearn.datasets.samples_generator import make_blobs, make_moons
X, y = make_blobs(n_samples=1000, centers=2, n_features=2,
                  random_state=0, cluster_std=0.25)

X, y = make_moons(n_samples=1000, random_state=0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Reescalamos los datos

# %%
X[:,0] = (X[:,0] - X[:,0].mean())/X[:,0].std()
X[:,1] = (X[:,1] - X[:,1].mean())/X[:,1].std()

# %%
sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
plt.show()

# %% [markdown]
# Definimos el modelo a entrenar y volvemos a mirar algunas de sus características.

# %%
model = Sequential()
# model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

# %%
optimizer = keras.optimizers.Adam(lr=0.001, beta_1=0.0, beta_2=0.0, decay=0.0, amsgrad=False)

model.compile(optimizer=optimizer,loss='binary_crossentropy',metrics=['accuracy'])

# %%
X.shape
# Out:
# (1000, 2)

# %%
history = model.fit(X, y, epochs=250, validation_split=0.25)
# Out:
# Train on 750 samples, validate on 250 samples
# Epoch 1/250
# 750/750 [==============================] - 0s 244us/step - loss: 0.9227 - accuracy: 0.2000 - val_loss: 0.8988 - val_accuracy: 0.2000
# Epoch 2/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.8486 - accuracy: 0.2120 - val_loss: 0.8275 - val_accuracy: 0.2120
# Epoch 3/250
# 750/750 [==============================] - 0s 90us/step - loss: 0.7796 - accuracy: 0.2400 - val_loss: 0.7626 - val_accuracy: 0.2240
# Epoch 4/250
# 750/750 [==============================] - 0s 106us/step - loss: 0.7176 - accuracy: 0.3387 - val_loss: 0.7039 - val_accuracy: 0.4800
# Epoch 5/250
# 750/750 [==============================] - 0s 94us/step - loss: 0.6616 - accuracy: 0.6373 - val_loss: 0.6519 - val_accuracy: 0.7000
# Epoch 6/250
# 750/750 [==============================] - 0s 112us/step - loss: 0.6128 - accuracy: 0.7560 - val_loss: 0.6058 - val_accuracy: 0.7280
# Epoch 7/250
# 750/750 [==============================] - 0s 109us/step - loss: 0.5705 - accuracy: 0.7813 - val_loss: 0.5657 - val_accuracy: 0.7440
# Epoch 8/250
# 750/750 [==============================] - 0s 88us/step - loss: 0.5331 - accuracy: 0.8027 - val_loss: 0.5311 - val_accuracy: 0.7720
# Epoch 9/250
# 750/750 [==============================] - 0s 125us/step - loss: 0.5018 - accuracy: 0.8120 - val_loss: 0.5010 - val_accuracy: 0.7960
# Epoch 10/250
# 750/750 [==============================] - 0s 89us/step - loss: 0.4738 - accuracy: 0.8173 - val_loss: 0.4742 - val_accuracy: 0.8120
# Epoch 11/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.4497 - accuracy: 0.8213 - val_loss: 0.4505 - val_accuracy: 0.8080
# Epoch 12/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.4281 - accuracy: 0.8267 - val_loss: 0.4288 - val_accuracy: 0.8160
# Epoch 13/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.4091 - accuracy: 0.8267 - val_loss: 0.4105 - val_accuracy: 0.8240
# Epoch 14/250
# 750/750 [==============================] - 0s 68us/step - loss: 0.3927 - accuracy: 0.8320 - val_loss: 0.3936 - val_accuracy: 0.8280
# Epoch 15/250
# 750/750 [==============================] - 0s 65us/step - loss: 0.3776 - accuracy: 0.8360 - val_loss: 0.3775 - val_accuracy: 0.8360
# Epoch 16/250
# 750/750 [==============================] - 0s 75us/step - loss: 0
250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 172/250
# 750/750 [==============================] - 0s 68us/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 173/250
# 750/750 [==============================] - 0s 101us/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 174/250
# 750/750 [==============================] - 0s 105us/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 175/250
# 750/750 [==============================] - 0s 68us/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 176/250
# 750/750 [==============================] - 0s 69us/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 177/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 178/250
# 750/750 [==============================] - 0s 68us/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 179/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 180/250
# 750/750 [==============================] - 0s 77us/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 181/250
# 750/750 [==============================] - 0s 79us/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 182/250
# 750/750 [==============================] - 0s 78us/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 183/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 184/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 185/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 186/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 187/250
# 750/750 [==============================] - 0s 80us/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 188/250
# 750/750 [==============================] - 0s 62us/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 189/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 190/250
# 750/750 [==============================] - 0s 92us/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 191/250
# 750/750 [==============================] - 0s 69us/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 192/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 193/250
# 750/750 [==============================] - 0s 72us/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 194/250
# 750/750 [==============================] - 0s 71us/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 195/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 196/250
# 750/750 [==============================] - 0s 63us/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 197/250
# 750/750 [==============================] - 0s 67us/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 198/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 199/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 200/250
# 750/750 [==============================] - 0s 89us/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 201/250
# 750/750 [==============================] - 0s 133us/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 202/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 203/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 204/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 205/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 206/250
# 750/750 [==============================] - 0s 81us/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 207/250
# 750/750 [==============================] - 0s 101us/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 208/250
# 750/750 [==============================] - 0s 77us/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 209/250
# 750/750 [==============================] - 0s 136us/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 210/250
# 750/750 [==============================] - 0s 69us/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 211/250
# 750/750 [==============================] - 0s 88us/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 212/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 213/250
# 750/750 [==============================] - 0s 102us/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 214/250
# 750/750 [==============================] - 0s 107us/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 215/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 216/250
# 750/750 [==============================] - 0s 84us/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 217/250
# 750/750 [==============================] - 0s 67us/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 218/250
# 750/750 [==============================] - 0s 71us/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 219/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 220/250
# 750/750 [==============================] - 0s 72us/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 221/250
# 750/750 [==============================] - 0s 111us/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 222/250
# 750/750 [==============================] - 0s 107us/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 223/250
# 750/750 [==============================] - 0s 85us/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 224/250
# 750/750 [==============================] - 0s 94us/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 225/250
# 750/750 [==============================] - 0s 74us/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 226/250
# 750/750 [==============================] - 0s 79us/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 227/250
# 750/750 [==============================] - 0s 83us/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 228/250
# 750/750 [==============================] - 0s 71us/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 229/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 230/250
# 750/750 [==============================] - 0s 66us/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 231/250
# 750/750 [==============================] - 0s 66us/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 232/250
# 750/750 [==============================] - 0s 82us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 233/250
# 750/750 [==============================] - 0s 97us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 234/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 235/250
# 750/750 [==============================] - 0s 73us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.7636e-04 - val_accuracy: 1.0000
# Epoch 236/250
# 750/750 [==============================] - 0s 66us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.6171e-04 - val_accuracy: 1.0000
# Epoch 237/250
# 750/750 [==============================] - 0s 75us/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 9.1228e-04 - val_accuracy: 1.0000
# Epoch 238/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 8.7602e-04 - val_accuracy: 1.0000
# Epoch 239/250
# 750/750 [==============================] - 0s 66us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 8.4488e-04 - val_accuracy: 1.0000
# Epoch 240/250
# 750/750 [==============================] - 0s 76us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 8.2584e-04 - val_accuracy: 1.0000
# Epoch 241/250
# 750/750 [==============================] - 0s 69us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 8.2969e-04 - val_accuracy: 1.0000
# Epoch 242/250
# 750/750 [==============================] - 0s 66us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 8.2490e-04 - val_accuracy: 1.0000
# Epoch 243/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.7227e-04 - val_accuracy: 1.0000
# Epoch 244/250
# 750/750 [==============================] - 0s 70us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.6003e-04 - val_accuracy: 1.0000
# Epoch 245/250
# 750/750 [==============================] - 0s 77us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 7.2596e-04 - val_accuracy: 1.0000
# Epoch 246/250
# 750/750 [==============================] - 0s 61us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.8786e-04 - val_accuracy: 1.0000
# Epoch 247/250
# 750/750 [==============================] - 0s 73us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.7354e-04 - val_accuracy: 1.0000
# Epoch 248/250
# 750/750 [==============================] - 0s 69us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.4751e-04 - val_accuracy: 1.0000
# Epoch 249/250
# 750/750 [==============================] - 0s 65us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.2118e-04 - val_accuracy: 1.0000
# Epoch 250/250
# 750/750 [==============================] - 0s 67us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.0934e-04 - val_accuracy: 1.0000

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %% [markdown]
# Notar que se agregaron una keys, asociadas al set de validación. Grafiquemos.

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ¿Cuántos parámetros tiene ahora el modelo?

# %%
print(model.get_weights())
# Out:
# [array([[-2.8513997 , -0.65000266, -0.03404559,  2.0289702 , -0.7896448 ,
#         -1.9043914 , -0.03546401, -0.02474713, -1.8835187 , -2.580716  ],
#        [-0.47456247,  0.36176974,  1.2419248 , -1.0094203 ,  0.1779153 ,
#         -0.82958955,  1.3066906 ,  0.9013568 , -0.1686105 , -0.23257062]],
#       dtype=float32), array([ 1.4696828 ,  1.2659826 , -0.45355043, -0.87600756,  1.358091  ,
#         0.83595043, -0.47882953, -0.32832935, -1.0194458 , -1.3983301 ],
#       dtype=float32), array([[ 3.1929452],
#        [-1.9879558],
#        [-2.541437 ],
#        [ 2.6202102],
#        [-2.3976133],
#        [ 3.3053448],
#        [-1.9825565],
#        [-1.8517848],
#        [-5.404024 ],
#        [-6.3977585]], dtype=float32), array([-0.88804656], dtype=float32)]

# %% [markdown]
# Y graficamos las fronteras de decisión. ¿Notan que ya no es una frontera abrupta, sino que hay una zona de cambio?¿A qué se debe?

# %%
plt.figure(figsize = (10,6))

ax = sns.scatterplot(x = X[:,0], y = X[:,1], hue = y)
xlim = ax.get_xlim()
ylim = ax.get_ylim()
xx, yy = np.meshgrid(np.linspace(*xlim, num=200),
                      np.linspace(*ylim, num=200))
Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
contours = ax.contourf(xx, yy, Z, levels = 10, alpha=0.3, cmap = 'plasma')
plt.show()

# %% [markdown]
# **Ejercicio:** volver a correr esta sección, pero reemplazando la función que genera los datos `make_blobs` por `make_moons`. ¿Qué problema ven en el resultado?
